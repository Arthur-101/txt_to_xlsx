# %%
from Test_04_X import DataProcessor

# %%
input_file = '65027 X.txt'
output_file = 'Output_Excel_X.xlsx'
data_processor = DataProcessor(input_file)

# %%
new_df = data_processor.new_df
percentage_count_df = data_processor.calculate_percentage_counts()
Subject_percentage_count_df = data_processor.calculate_subject_percentage_counts()
highest_marks_df = data_processor.calculate_highest_marks_students()

# %%
new_df = new_df.fillna('')
new_df
# Out:
#          Roll Gender                 Name   002 Grade_002  041 Grade_041  086  \
# 0    22141969      M  AARIN PRAKASH SINHA  71.0        C1   41        D1   36
# 1    22141970      M               ADARSH  78.0        B2   47        C2   51
# 2    22141971      M           ADARSH RAJ  82.0        B1   92        A1   86
# 3    22141972      M           ADARSH RAJ  65.0        C2   25         E   39
# 4    22141973      M         ADITYA KUMAR  87.0        A2   44        D1   53
# ..        ...    ...                  ...   ...       ...  ...       ...  ...
# 301  22142270      F         SWEETY SINHA                   86        A2   86
# 302  22142271      F            VAISHNAVI                   66        B2   62
# 303  22142272      F             VISHAKHA                   95        A1   95
# 304  22142273      F           ZAIRA KHAN                   99        A1   95
# 305  22142274      F    BHUMI DAYAL SINGH  88.0        A2   70        B1   71
#
# ...

# %%
percentage_count_df
# Out:
#    Percentage  Total No of student
# 0   Above 90%                   69
# 1  80% to 89%                   87
# 2  75% to 79%                   30
# 3  60% to 74%                   71
# 4   Below 60%                   28

# %%
Subject_percentage_count_df
# Out:
#    Sr. No.    Subject Name  90% and Above  80% To 89%  70% To 79%  60% To 69%  \
# 0        1         English             56          88          84          42
# 1        2           Hindi             38          91          60          28
# 2        3        Sanskrit             43          16          10           2
# 3        4           Maths             81          42          29          31
# 4        5         Science             56          56          43          41
# 5        6  Social Science            123          78          51          26
# 6        7            I.T.             45         128          93          36
#
#    Below 60%  Total Student
# 0         36            306
# 1         17            234
# 2          1             72
# 3        123            306
# 4        110            306
# 5         28            306
# 6          4            306

# %%
highest_marks_df
# Out:
#    Sr. No. Subject Codes    Subject Name  Highest Marks  \
# 0        1           184         English           97.0
# 1        2           002           Hindi           95.0
# 2        3           122        Sanskrit          100.0
# 3        4           041           Maths          100.0
# 4        5           086         Science           99.0
# 5        6           087  Social Science          100.0
# 6        7           402            I.T.           99.0
#
#                                      Name of Toppers
# 0      SHIVAM SINHA, SHIVANSH KUMAR, SHUBHRA SARJANA
# 1  ACHINTYA, SATYAM KUMAR, SHIVANG VATS, FARHEEN ...
# 2                                    SHUBHRA SARJANA
# 3                                     SHIVANSH KUMAR
# 4                                    SONIKA RAJSHREE
# 5                        FARHEEN NAAZ, SALONI KUMARI
# 6                                      SALONI KUMARI

# %%
data_processor.save_data_to_excel(output_file)

# %%
data_processor.save_analysis_to_excel(output_file)
