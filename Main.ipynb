# %%
from Filter_X import DataProcessor_X
from Filter_XII import DataProcessor_XII

# %%
input_file_X = '65027 X.txt'
input_file_XII = '65027 XII.txt'
output_file_X = 'Result_Analysis_X.xlsx'
output_file_XII = 'Result_Analysis_XII.xlsx'
data_processor_X = DataProcessor_X(input_file_X)
data_processor_XII = DataProcessor_XII(input_file_XII)
# Out:
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.science_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.commerce_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.commerce_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.commerce_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.commerce_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.commerce_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.commerce_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcm_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)
# c:\Users\dell\Documents\Python codes\txt_to_xlsx\txt_to_xlsx\Filter_XII.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.pcb_df.drop(columns=[col], inplace=True)

# %%
show_df_X = data_processor_X.show_df
percentage_count_df_X = data_processor_X.calculate_percentage_counts()
Subject_percentage_count_df_X = data_processor_X.calculate_subject_percentage_counts()
highest_marks_df_X = data_processor_X.calculate_highest_marks_students()

# %%
show_df_X
# Out:
#          Roll Gender                 Name Hindi Grade Hindi  Maths  \
# 0    22141969      M  AARIN PRAKASH SINHA  71.0          C1     41
# 1    22141970      M               ADARSH  78.0          B2     47
# 2    22141971      M           ADARSH RAJ  82.0          B1     92
# 3    22141972      M           ADARSH RAJ  65.0          C2     25
# 4    22141973      M         ADITYA KUMAR  87.0          A2     44
# ..        ...    ...                  ...   ...         ...    ...
# 301  22142270      F         SWEETY SINHA                       86
# 302  22142271      F            VAISHNAVI                       66
# 303  22142272      F             VISHAKHA                       95
# 304  22142273      F           ZAIRA KHAN                       99
# 305  22142274      F    BHUMI DAYAL SINGH  88.0          A2     70
#
#     Grade Maths  Science Grade Science  Social Science Grade Social Science  \
# 0            D1       36            D2              81                   B1
# 1            C2       51            C2              83                   B1
# 2            A1       86            A2              92                   A2
# 3             E       39            D1              61                   C2
# 4            D1       53            C1              88                   A2
# ..          ...      ...           ...             ...                  ...
# 301          A2       86            A2              91                   A2
# 302          B2       62            B2              91                   A2
# 303          A1       95            A1              94                   A1
# 304          A1       95            A1              98                   A1
# 305          B1       71            B1              89                   A2
#
#     Sanskrit Grade Sanskrit  English Grade English  I.T. Grade I.T.  \
# 0                                 47            D1    70         C2
# 1                                 83            B1    81         B2
# 2                                 78            B1    83         B2
# 3                                 39            D2    79         C1
# 4                                 61            C2    78         C1
# ..       ...            ...      ...           ...   ...        ...
# 301     96.0             A1       90            A1    81         B2
# 302     82.0             A2       91            A1    79         C1
# 303     96.0             A1       93            A1    86         B1
# 304     99.0             A1       92            A1    92         A2
# 305                               93            A1    75         C1
#
#      Total Marks  Total Marks (Best 5)  Percentage (%)
# 0            346                   310            62.0
# 1            423                   376            75.2
# 2            513                   435            87.0
# 3            308                   283            56.6
# 4            411                   367            73.4
# ..           ...                   ...             ...
# 301          530                   449            89.8
# 302          471                   409            81.8
# 303          559                   473            94.6
# 304          575                   483            96.6
# 305          486                   416            83.2
#
# [306 rows x 20 columns]

# %%
percentage_count_df_X
# Out:
#    Percentage  Total No of student
# 0   Above 90%                   69
# 1  80% to 89%                   87
# 2  75% to 79%                   30
# 3  60% to 74%                   71
# 4   Below 60%                   28

# %%
Subject_percentage_count_df_X
# Out:
#    Sr. No. Subject Codes    Subject Name  90% and Above  80% To 89%  \
# 0        1           184         English             56          88
# 1        2           002           Hindi             38          91
# 2        3           122        Sanskrit             43          16
# 3        4           041           Maths             81          42
# 4        5           086         Science             56          56
# 5        6           087  Social Science            123          78
# 6        7           402            I.T.             45         128
#
#    70% To 79%  60% To 69%  Below 60%  Total Student
# 0          84          42         36          306.0
# 1          60          28         17          234.0
# 2          10           2          1           72.0
# 3          29          31        123          306.0
# 4          43          41        110          306.0
# 5          51          26         28          306.0
# 6          93          36          4          306.0

# %%
highest_marks_df_X
# Out:
#    Sr. No. Subject Codes    Subject Name  Highest Marks  \
# 0        1           184         English           97.0
# 1        2           002           Hindi           95.0
# 2        3           122        Sanskrit          100.0
# 3        4           041           Maths          100.0
# 4        5           086         Science           99.0
# 5        6           087  Social Science          100.0
# 6        7           402            I.T.           99.0
#
#                                      Name of Toppers
# 0      SHIVAM SINHA, SHIVANSH KUMAR, SHUBHRA SARJANA
# 1  ACHINTYA, SATYAM KUMAR, SHIVANG VATS, FARHEEN ...
# 2                                    SHUBHRA SARJANA
# 3                                     SHIVANSH KUMAR
# 4                                    SONIKA RAJSHREE
# 5                        FARHEEN NAAZ, SALONI KUMARI
# 6                                      SALONI KUMARI

# %%
data_processor_X.save_data_to_excel(output_file_X)

# %%
data_processor_X.save_analysis_to_excel(output_file_X)

# %%
show_df_XII = data_processor_XII.show_df
show_df_science = data_processor_XII.science_df
show_df_pcm = data_processor_XII.pcm_df
show_df_pcb = data_processor_XII.pcb_df
show_df_commerce = data_processor_XII.commerce_df
percentage_count_df_XII = data_processor_XII.calculate_percentage_counts()
Subject_percentage_count_df_XII = data_processor_XII.calculate_subject_percentage_counts()
highest_marks_df_XII = data_processor_XII.calculate_highest_marks_students()

# %%
show_df_XII
# Out:
#          Roll Gender              Name Economics Grade Economics Maths  \
# 0    22614342      M   ABHIMANYU KUMAR                            51.0
# 1    22614343      F    AKANKSHA PRIYA                            75.0
# 2    22614344      F   AKANKSHI KUMARI                            95.0
# 3    22614345      M        AKEE KUMAR                            55.0
# 4    22614346      M        AMAN KUMAR                            53.0
# ..        ...    ...               ...       ...             ...   ...
# 312  22614654      F    VAANI BHANWALA
# 313  22614655      F       RASHI SINHA      70.0              B2
# 314  22614656      M        AAYUSH RAJ                            19.0
# 315  22614657      M        KRISHI RAJ
# 316  22614658      M  SHASHIKESH KUMAR       0.0               E
#
#     Grade Maths Physics Grade Physics Chemistry  ... Grade English Hindi  \
# 0            D1    63.0            C1      52.0  ...            B2  80.0
# 1            B1    79.0            A2      74.0  ...            A2  76.0
# 2            A1    95.0            A1      95.0  ...            B1
# 3            C1    66.0            B2      59.0  ...            D1
# 4            C2    62.0            C1      65.0  ...            B2  74.0
# ..          ...     ...           ...       ...  ...           ...   ...
# 312                68.0            B2      69.0  ...            B2
# 313                                              ...            A1
# 314           E     0.0             E       0.0  ...             E
# 315                 0.0             E       0.0  ...             E
# 316                                              ...             E   0.0
#
#     Grade Hindi Sanskrit Grade Sanskrit   802 Grade_802 Total Marks  \
# 0            B1                                                 405
# 1            B2                                                 484
# 2                   98.0             A1                         556
# 3                                                               393
# 4            B2                                                 418
# ..          ...      ...            ...   ...       ...         ...
# 312                                                             374
# 313                                      89.0        A2         447
# 314                                                              49
# 315                                                              30
# 316           E                                                   0
#
#     Total Marks (Best 5) Percentage (%)
# 0                    354           70.8
# 1                    410           82.0
# 2                    472           94.4
# 3                    339           67.8
# 4                    365           73.0
# ..                   ...            ...
# 312                  374           74.8
# 313                  393           78.6
# 314                   49            9.8
# 315                   30            6.0
# 316                    0            0.0
#
# [317 rows x 34 columns]

# %%
show_df_science
# Out:
#          Roll Gender             Name Maths Grade Maths Physics Grade Physics  \
# 0    22614342      M  ABHIMANYU KUMAR  51.0          D1    63.0            C1
# 1    22614343      F   AKANKSHA PRIYA  75.0          B1    79.0            A2
# 2    22614344      F  AKANKSHI KUMARI  95.0          A1    95.0            A1
# 3    22614345      M       AKEE KUMAR  55.0          C1    66.0            B2
# 4    22614346      M       AMAN KUMAR  53.0          C2    62.0            C1
# ..        ...    ...              ...   ...         ...     ...           ...
# 215  22614557      F        ZOHA AYAZ                      70.0            B1
# 216  22614653      M    AADITYA KUMAR                      63.0            C1
# 217  22614654      F   VAANI BHANWALA                      68.0            B2
# 218  22614656      M       AAYUSH RAJ  19.0           E     0.0             E
# 219  22614657      M       KRISHI RAJ                       0.0             E
#
#     Chemistry Grade Chemistry Biology  ... Grade I.P. English Grade English  \
# 0        52.0              D2          ...                 76            B2
# 1        74.0              B1          ...                 86            A2
# 2        95.0              A1          ...                 84            B1
# 3        59.0              C2          ...         C2      54            D1
# 4        65.0              C1          ...                 79            B2
# ..        ...             ...     ...  ...        ...     ...           ...
# 215      66.0              B2    71.0  ...         C2      89            A2
# 216      52.0              D2    67.0  ...         C2      81            B1
# 217      69.0              B2    63.0  ...                 79            B2
# 218       0.0               E          ...          E       0             E
# 219       0.0               E     0.0  ...          E       0             E
#
#     Hindi Grade Hindi  Sanskrit Grade Sanskrit Total Marks  \
# 0    80.0          B1                                  405
# 1    76.0          B2                                  484
# 2                          98.0             A1         556
# 3                                                      393
# 4    74.0          B2                                  418
# ..    ...         ...       ...            ...         ...
# 215                                                    464
# 216                                                    417
# 217                                                    374
# 218                                                     49
# 219                                                     30
#
#     Total Marks (Best 5) Percentage (%)
# 0                    354           70.8
# 1                    410           82.0
# 2                    472           94.4
# 3                    339           67.8
# 4                    365           73.0
# ..                   ...            ...
# 215                  398           79.6
# 216                  365           73.0
# 217                  374           74.8
# 218                   49            9.8
# 219                   30            6.0
#
# [220 rows x 24 columns]

# %%
show_df_pcm
# Out:
#          Roll Gender               Name Maths Grade Maths Physics  \
# 0    22614342      M    ABHIMANYU KUMAR  51.0          D1    63.0
# 1    22614343      F     AKANKSHA PRIYA  75.0          B1    79.0
# 2    22614344      F    AKANKSHI KUMARI  95.0          A1    95.0
# 3    22614345      M         AKEE KUMAR  55.0          C1    66.0
# 4    22614346      M         AMAN KUMAR  53.0          C2    62.0
# ..        ...    ...                ...   ...         ...     ...
# 144  22614538      F     SHIVANI KUMARI  56.0          C1    92.0
# 145  22614540      F       SHYAMA YADAV  53.0          C2    52.0
# 146  22614543      M  SUNNY KUMAR SINGH  52.0          C2    68.0
# 147  22614550      F           TANU RAJ  45.0          D2    66.0
# 148  22614656      M         AAYUSH RAJ  19.0           E     0.0
#
#     Grade Physics Chemistry Grade Chemistry Biology  ... Grade I.P. English  \
# 0              C1      52.0              D2          ...                 76
# 1              A2      74.0              B1          ...                 86
# 2              A1      95.0              A1          ...                 84
# 3              B2      59.0              C2          ...         C2      54
# 4              C1      65.0              C1          ...                 79
# ..            ...       ...             ...     ...  ...        ...     ...
# 144            A1      82.0              A2    89.0  ...                 81
# 145            D1      59.0              C2    58.0  ...                 71
# 146            B2      65.0              C1    80.0  ...                 81
# 147            B2      61.0              C1    62.0  ...                 85
# 148             E       0.0               E          ...          E       0
#
#     Grade English Hindi Grade Hindi  Sanskrit Grade Sanskrit Total Marks  \
# 0              B2  80.0          B1                                  405
# 1              A2  76.0          B2                                  484
# 2              B1                        98.0             A1         556
# 3              D1                                                    393
# 4              B2  74.0          B2                                  418
# ..            ...   ...         ...       ...            ...         ...
# 144            B1                                                    479
# 145            C1                                                    376
# 146            B1                                                    429
# 147            B1                                                    409
# 148             E                                                     49
#
#     Total Marks (Best 5) Percentage (%)
# 0                    354           70.8
# 1                    410           82.0
# 2                    472           94.4
# 3                    339           67.8
# 4                    365           73.0
# ..                   ...            ...
# 144                  423           84.6
# 145                  324           64.8
# 146                  377           75.4
# 147                  364           72.8
# 148                   49            9.8
#
# [149 rows x 24 columns]

# %%
show_df_pcb
# Out:
#         Roll Gender            Name Maths Grade Maths Physics Grade Physics  \
# 0   22614469      M    ADITYA KUMAR                      93.0            A1
# 1   22614470      M    ADITYA KUMAR                      52.0            D1
# 2   22614471      F   AIYSHA KUMARI                      62.0            C1
# 3   22614472      M     AMEET KUMAR  59.0          C1    70.0            B1
# 4   22614473      F  ANANYA PRAKASH                      83.0            A2
# ..       ...    ...             ...   ...         ...     ...           ...
# 87  22614556      F      YUKTI SONI                      73.0            B1
# 88  22614557      F       ZOHA AYAZ                      70.0            B1
# 89  22614653      M   AADITYA KUMAR                      63.0            C1
# 90  22614654      F  VAANI BHANWALA                      68.0            B2
# 91  22614657      M      KRISHI RAJ                       0.0             E
#
#    Chemistry Grade Chemistry Biology  ... Grade I.P. English Grade English  \
# 0       92.0              A1    95.0  ...         A2      76            B2
# 1       51.0              D2    53.0  ...                 55            D1
# 2       60.0              C2    68.0  ...         D1      81            B1
# 3       76.0              B1    79.0  ...                 68            C2
# 4       90.0              A2    91.0  ...         B1      88            A2
# ..       ...             ...     ...  ...        ...     ...           ...
# 87      53.0              D1    58.0  ...                 80            B2
# 88      66.0              B2    71.0  ...         C2      89            A2
# 89      52.0              D2    67.0  ...         C2      81            B1
# 90      69.0              B2    63.0  ...                 79            B2
# 91       0.0               E     0.0  ...          E       0             E
#
#    Hindi Grade Hindi  Sanskrit Grade Sanskrit Total Marks  \
# 0                                                     547
# 1   59.0          D1                                  337
# 2                                                     424
# 3                                                     439
# 4                                                     537
# ..   ...         ...       ...            ...         ...
# 87  75.0          B2                                  426
# 88                                                    464
# 89                                                    417
# 90                                                    374
# 91                                                     30
#
#    Total Marks (Best 5) Percentage (%)
# 0                   471           94.2
# 1                   286           57.2
# 2                   364           72.8
# 3                   380           76.0
# 4                   454           90.8
# ..                  ...            ...
# 87                  373           74.6
# 88                  398           79.6
# 89                  365           73.0
# 90                  374           74.8
# 91                   30            6.0
#
# [92 rows x 24 columns]

# %%
show_df_commerce
# Out:
#         Roll Gender                    Name Economics Grade Economics Maths  \
# 0   22614558      F                 AAKRITI      58.0              C2  54.0
# 1   22614559      M           ABHINAV SINGH      87.0              A2  53.0
# 2   22614560      M          ADITYA BHUSHAN      65.0              C1  56.0
# 3   22614561      M            ADITYA KUMAR      50.0              D1
# 4   22614562      M              ADITYA RAJ      53.0              C2
# ..       ...    ...                     ...       ...             ...   ...
# 92  22614650      F             TANISHA RAJ      86.0              A2  59.0
# 93  22614651      F  TRUSHALI CHARAN PAHARI      74.0              B1  54.0
# 94  22614652      M             VARUN KUMAR      80.0              B1
# 95  22614655      F             RASHI SINHA      70.0              B2
# 96  22614658      M        SHASHIKESH KUMAR       0.0               E
#
#    Grade Maths Physicsl Education Grade Physicsl Education Business Studies  \
# 0           C2               73.0                       C1             76.0
# 1           C2               84.0                       B1             87.0
# 2           C1               76.0                       B2             68.0
# 3                            64.0                       C2             65.0
# 4                            79.0                       B2             61.0
# ..         ...                ...                      ...              ...
# 92          C1               97.0                       A1             87.0
# 93          C2               84.0                       B1             82.0
# 94                           88.0                       A2             74.0
# 95                                                                     77.0
# 96                            0.0                        E              0.0
#
#     ... Grade English Hindi Grade Hindi Sanskrit Grade Sanskrit   802  \
# 0   ...            B2
# 1   ...            C1
# 2   ...            C1
# 3   ...            D1  62.0          D1
# 4   ...            C1
# ..  ...           ...   ...         ...      ...            ...   ...
# 92  ...            B1
# 93  ...            B2
# 94  ...            B2  82.0          B1
# 95  ...            A1                                            89.0
# 96  ...             E   0.0           E
#
#    Grade_802  Total Marks Total Marks (Best 5) Percentage (%)
# 0                     390                  338           67.6
# 1                     471                  418           83.6
# 2                     400                  344           68.8
# 3                     357                  307           61.4
# 4                     397                  346           69.2
# ..       ...          ...                  ...            ...
# 92                    501                  442           88.4
# 93                    447                  393           78.6
# 94                    473                  402           80.4
# 95        A2          447                  393           78.6
# 96                      0                    0            0.0
#
# [97 rows x 28 columns]

# %%
percentage_count_df_XII
# Out:
#    Percentage  Total No of student
# 0   Above 90%                   38
# 1  80% to 89%                   84
# 2  75% to 79%                   48
# 3  60% to 74%                  121
# 4   Below 60%                    7

# %%
Subject_percentage_count_df_XII
# Out:
#     Sr. No. Subject Codes        Subject Name  90% and Above  80% To 89%  \
# 0         1           041               Maths             17          12
# 1         2           042             Physics             21          35
# 2         3           043           Chemistry             19          30
# 3         4           044             Biology             14          22
# 4         5           301             English             31         143
# 5         6           048  Physical Education            106         132
# 6         7           030           Economics             12          28
# 7         8           054    Business Studies             30          25
# 8         9           055         Accountancy             18          14
# 9        10           302               Hindi              8          27
# 10       11           322            Sanskrit              7           3
# 11       12           065                I.P.             31          44
#
#     70% To 79%  60% To 69%  Below 60%  Total Student
# 0           21          39         96          185.0
# 1           33          78         53          220.0
# 2           29          62         80          220.0
# 3           14          22         20           92.0
# 4          101          32         10          317.0
# 5           58          16          4          316.0
# 6           26          18         13           97.0
# 7           20          14          8           97.0
# 8           10          14         41           97.0
# 9           34          16          8           93.0
# 10           2           1          0           13.0
# 11          44          27          6          152.0

# %%
highest_marks_df_XII
# Out:
#     Sr. No. Subject Codes        Subject Name  Highest Marks  \
# 0         1           041               Maths           98.0
# 1         2           042             Physics           96.0
# 2         3           043           Chemistry           95.0
# 3         4           044             Biology           97.0
# 4         5           301             English           97.0
# 5         6           048  Physical Education           98.0
# 6         7           030           Economics           96.0
# 7         8           054    Business Studies           99.0
# 8         9           055         Accountancy           99.0
# 9        10           302               Hindi           94.0
# 10       11           322            Sanskrit          100.0
# 11       12           065                I.P.           99.0
#
#                                       Name of Toppers
# 0                                      SANJANA KUMARI
# 1                                        ANJALI YADAV
# 2   AKANKSHI KUMARI, GUNGUN, SUNNY KUMAR, ANJALI Y...
# 3                                         SWATI PRIYA
# 4                                         KHUSHI RANI
# 5   SUNNY KUMAR, ADITYA RAJ, SHIVAM KUMAR AMRESH, ...
# 6                                       ANSAL AGRAWAL
# 7                         KHUSHI RANI, KUSHAGRA KUMAR
# 8                             HARSH RAJ, NAVEEN KUMAR
# 9                                           AYUSH RAJ
# 10                                GUNGUN, SUNNY KUMAR
# 11                                        AYUSH KUMAR

# %%
data_processor_XII.save_data_to_excel(output_file_XII)

# %%
data_processor_XII.save_analysis_to_excel(output_file_XII)
